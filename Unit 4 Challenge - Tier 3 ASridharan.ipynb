# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
### Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
#Exploring the dataframe
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties.shape
# Out:
# (322, 49)

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
#Transposing the dataframe
properties = properties.transpose()

# %%
#Confirming Transpose
properties.shape
# Out:
# (49, 322)

# %%
#Reviewing current indices
properties.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
#Resetting indices
properties = properties.reset_index()

# %%
#Making first row of Dataframe to column names
properties.columns = properties.iloc[0]

# %%
#Dropping first row
properties = properties.drop(properties.index[0])

# %%
properties.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
#Renaming first two columns columns
properties = properties.rename(columns={'Unnamed: 0': 'Boroughs', pd.NaT: 'Bcode'})

# %%
properties.head()
# Out:
# 0            Boroughs      Bcode 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
#Melting dataframe to convert from wide to tall
properties_melted = properties.melt(id_vars=['Boroughs','Bcode'],var_name=['Month'],value_name='Prices')

# %%
properties_melted.head(20)
# Out:
#                 Boroughs      Bcode      Month       Prices
# 0         City of London  E09000001 1995-01-01  91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.2266
# 2                 Barnet  E09000003 1995-01-01  93284.51832
# 3                 Bexley  E09000004 1995-01-01  64958.09036
# 4                  Brent  E09000005 1995-01-01  71306.56698
# 5                Bromley  E09000006 1995-01-01  81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.8881
# 7                Croydon  E09000008 1995-01-01  69158.16225
# 8                 Ealing  E09000009 1995-01-01  79885.89069
# 9                Enfield  E09000010 1995-01-01  72514.69096
# 10             Greenwich  E09000011 1995-01-01  62300.10169
# 11               Hackney  E09000012 1995-01-01  61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.8602
# 13              Haringey  E09000014 1995-01-01  76287.56947
# 14                Harrow  E09000015 1995-01-01  84769.52599
# ...

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
#Checking the datatypes of the columns
properties_melted.dtypes
# Out:
# Boroughs            object
# Bcode               object
# Month       datetime64[ns]
# Prices              object
# dtype: object

# %%
#Converting datatype of the prices columns
properties_melted['Prices'] = pd.to_numeric(properties_melted['Prices'],errors='coerce')

# %%
#Confirming conversion
properties_melted.dtypes
# Out:
# Boroughs            object
# Bcode               object
# Month       datetime64[ns]
# Prices             float64
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
#Checking for number of observations
properties_melted.count()
# Out:
# Boroughs    15408
# Bcode       14445
# Month       15408
# Prices      14442
# dtype: int64

# %%
#Checking for number of boroughs in dataframe
properties_melted['Boroughs'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
#Reviewing dataframe for missing and irrelevant values
properties_melted[properties_melted['Bcode'].isna()]
# Out:
#           Boroughs Bcode      Month  Prices
# 33     Unnamed: 34   NaN 1995-01-01     NaN
# 36     Unnamed: 37   NaN 1995-01-01     NaN
# 46     Unnamed: 47   NaN 1995-01-01     NaN
# 81     Unnamed: 34   NaN 1995-02-01     NaN
# 84     Unnamed: 37   NaN 1995-02-01     NaN
# ...            ...   ...        ...     ...
# 15348  Unnamed: 37   NaN 2021-08-01     NaN
# 15358  Unnamed: 47   NaN 2021-08-01     NaN
# 15393  Unnamed: 34   NaN 2021-09-01     NaN
# 15396  Unnamed: 37   NaN 2021-09-01     NaN
# 15406  Unnamed: 47   NaN 2021-09-01     NaN
#
# [963 rows x 4 columns]

# %%
properties_melted[properties_melted['Boroughs']== 'Unnamed: 34'].head(5)
# Out:
#         Boroughs Bcode      Month  Prices
# 33   Unnamed: 34   NaN 1995-01-01     NaN
# 81   Unnamed: 34   NaN 1995-02-01     NaN
# 129  Unnamed: 34   NaN 1995-03-01     NaN
# 177  Unnamed: 34   NaN 1995-04-01     NaN
# 225  Unnamed: 34   NaN 1995-05-01     NaN

# %%
properties_melted[properties_melted['Boroughs']== 'Unnamed: 37'].head(5)
# Out:
#         Boroughs Bcode      Month  Prices
# 36   Unnamed: 37   NaN 1995-01-01     NaN
# 84   Unnamed: 37   NaN 1995-02-01     NaN
# 132  Unnamed: 37   NaN 1995-03-01     NaN
# 180  Unnamed: 37   NaN 1995-04-01     NaN
# 228  Unnamed: 37   NaN 1995-05-01     NaN

# %%
#Removing all NaN values from the dataframe
NanFreeProperties = properties_melted.dropna()

# %%
NanFreeProperties.head(50)
# Out:
#                 Boroughs      Bcode      Month        Prices
# 0         City of London  E09000001 1995-01-01   91448.98487
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                 Barnet  E09000003 1995-01-01   93284.51832
# 3                 Bexley  E09000004 1995-01-01   64958.09036
# 4                  Brent  E09000005 1995-01-01   71306.56698
# 5                Bromley  E09000006 1995-01-01   81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 7                Croydon  E09000008 1995-01-01   69158.16225
# 8                 Ealing  E09000009 1995-01-01   79885.89069
# 9                Enfield  E09000010 1995-01-01   72514.69096
# 10             Greenwich  E09000011 1995-01-01   62300.10169
# 11               Hackney  E09000012 1995-01-01   61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 13              Haringey  E09000014 1995-01-01   76287.56947
# ...

# %%
NanFreeProperties.shape
# Out:
# (14442, 4)

# %%
#Creating list of non-boroughs
NotBoroughs = ['City of London','Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
#Making a new dataframe with only boroughs
OnlyBoroughs = NanFreeProperties[~NanFreeProperties.Boroughs.isin(NotBoroughs)]

# %%
OnlyBoroughs.head(50)
# Out:
#                 Boroughs      Bcode      Month        Prices
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660
# 2                 Barnet  E09000003 1995-01-01   93284.51832
# 3                 Bexley  E09000004 1995-01-01   64958.09036
# 4                  Brent  E09000005 1995-01-01   71306.56698
# 5                Bromley  E09000006 1995-01-01   81671.47692
# 6                 Camden  E09000007 1995-01-01  120932.88810
# 7                Croydon  E09000008 1995-01-01   69158.16225
# 8                 Ealing  E09000009 1995-01-01   79885.89069
# 9                Enfield  E09000010 1995-01-01   72514.69096
# 10             Greenwich  E09000011 1995-01-01   62300.10169
# 11               Hackney  E09000012 1995-01-01   61296.52637
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020
# 13              Haringey  E09000014 1995-01-01   76287.56947
# 14                Harrow  E09000015 1995-01-01   84769.52599
# ...

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
#Preliminary visualization of a single borough, Brent to look at the data trend
OnlyBrent = OnlyBoroughs[OnlyBoroughs['Boroughs'] == 'Brent']

# %%
#Line plot of price change over the years for Brent
ax = OnlyBrent.plot.line(x='Month',y='Prices')
ax.set_ylabel('Price')
ax.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
#Adding an additional column to extra year from Month column 
OnlyBoroughs['Year'] = OnlyBoroughs['Month'].dt.year
# Out:
# /var/folders/n2/3jm0yqh50tqgthxmrbtwhjh40000gn/T/ipykernel_85633/2212560289.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   OnlyBoroughs['Year'] = OnlyBoroughs['Month'].dt.year

# %%
OnlyBoroughs.head(33)
# Out:
#                 Boroughs      Bcode      Month        Prices  Year
# 1     Barking & Dagenham  E09000002 1995-01-01   50460.22660  1995
# 2                 Barnet  E09000003 1995-01-01   93284.51832  1995
# 3                 Bexley  E09000004 1995-01-01   64958.09036  1995
# 4                  Brent  E09000005 1995-01-01   71306.56698  1995
# 5                Bromley  E09000006 1995-01-01   81671.47692  1995
# 6                 Camden  E09000007 1995-01-01  120932.88810  1995
# 7                Croydon  E09000008 1995-01-01   69158.16225  1995
# 8                 Ealing  E09000009 1995-01-01   79885.89069  1995
# 9                Enfield  E09000010 1995-01-01   72514.69096  1995
# 10             Greenwich  E09000011 1995-01-01   62300.10169  1995
# 11               Hackney  E09000012 1995-01-01   61296.52637  1995
# 12  Hammersmith & Fulham  E09000013 1995-01-01  124902.86020  1995
# 13              Haringey  E09000014 1995-01-01   76287.56947  1995
# ...

# %%
OnlyBoroughs.tail(10)
# Out:
#                    Boroughs      Bcode      Month       Prices  Year
# 15383                Merton  E09000024 2021-09-01  555225.5399  2021
# 15384                Newham  E09000025 2021-09-01  365357.1433  2021
# 15385             Redbridge  E09000026 2021-09-01  480339.9440  2021
# 15386  Richmond upon Thames  E09000027 2021-09-01  735675.2191  2021
# 15387             Southwark  E09000028 2021-09-01  536755.5255  2021
# 15388                Sutton  E09000029 2021-09-01  415227.6650  2021
# 15389         Tower Hamlets  E09000030 2021-09-01  440846.7361  2021
# 15390        Waltham Forest  E09000031 2021-09-01  505389.1863  2021
# 15391            Wandsworth  E09000032 2021-09-01  599124.4127  2021
# 15392           Westminster  E09000033 2021-09-01  965766.3554  2021

# %%
#Grouping boroughs by year and evaluating the yearly average price
BoroughsByYear = OnlyBoroughs.groupby(by=['Boroughs','Year']).mean()

# %%
BoroughsByYear.head(10)
# Out:
#                                 Prices
# Boroughs           Year
# Barking & Dagenham 1995   51817.969390
#                    1996   51718.192690
#                    1997   55974.262309
#                    1998   60285.821083
#                    1999   65320.934441
#                    2000   77549.513290
#                    2001   88664.058223
#                    2002  112221.912482
#                    2003  142498.927800
#                    2004  158175.982483

# %%
BoroughsByYear = BoroughsByYear.reset_index()

# %%
BoroughsByYear.head()
# Out:
#              Boroughs  Year        Prices
# 0  Barking & Dagenham  1995  51817.969390
# 1  Barking & Dagenham  1996  51718.192690
# 2  Barking & Dagenham  1997  55974.262309
# 3  Barking & Dagenham  1998  60285.821083
# 4  Barking & Dagenham  1999  65320.934441

# %%
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Hackney'][BoroughsByYear['Year']==2020])
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Hackney'][BoroughsByYear['Year']==2000])
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Waltham Forest'][BoroughsByYear['Year']==2020])
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Waltham Forest'][BoroughsByYear['Year']==2000])
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Newham'][BoroughsByYear['Year']==2020])
print(BoroughsByYear['Prices'][BoroughsByYear['Boroughs']=='Newham'][BoroughsByYear['Year']==2000])
# Out:
# 295    582295.425142
# Name: Prices, dtype: float64
# 275    132727.506075
# Name: Prices, dtype: float64
# 808    450012.3963
# Name: Prices, dtype: float64
# 788    103030.676566
# Name: Prices, dtype: float64
# 646    371432.765292
# Name: Prices, dtype: float64
# 626    92887.329294
# Name: Prices, dtype: float64

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
#Defining the create_price_ratio function to look at the price ratio as well as price percentage change
def create_price_ratio(B):
    avgPrice2020 = float(B['Prices'][B['Year']==2020])
    avgPrice2000 = float(B['Prices'][B['Year']==2000])
    ratio = avgPrice2020/avgPrice2000
    per_change = ((avgPrice2020 - avgPrice2000)/(avgPrice2000))*100
    metrics = (ratio, per_change)
    return metrics

# %%
#Testing the function
create_price_ratio(BoroughsByYear[BoroughsByYear['Boroughs']=='Brent'])
# Out:
# (3.446670779724697, 244.66707797246966)

# %%
#Performing evaluation for all Boroughs
AllBoroughMetrics = {}

# %%
for i in BoroughsByYear['Boroughs'].unique():
    borough = BoroughsByYear[BoroughsByYear['Boroughs']== i]
    AllBoroughMetrics[i] = create_price_ratio(borough)
print(AllBoroughMetrics)
# Out:
# {'Barking & Dagenham': (3.8961309290034536, 289.61309290034535), 'Barnet': (3.130526809007584, 213.05268090075847), 'Bexley': (3.3245075326616718, 232.45075326616717), 'Brent': (3.446670779724697, 244.66707797246966), 'Bromley': (2.941011940274816, 194.1011940274816), 'Camden': (3.358211634121892, 235.8211634121892), 'Croydon': (3.1570429428061266, 215.70429428061266), 'Ealing': (3.128507691877485, 212.8507691877485), 'Enfield': (3.2501203164980446, 225.01203164980444), 'Greenwich': (3.5891974687052866, 258.9197468705287), 'Hackney': (4.387149599666481, 338.71495996664805), 'Hammersmith & Fulham': (2.9459947465596765, 194.59947465596764), 'Haringey': (3.833315610643174, 283.3315610643174), 'Harrow': (2.9728667890228726, 197.2866789022872), 'Havering': (3.3843558032905743, 238.43558032905742), 'Hillingdon': (3.1181360265778104, 211.81360265778105), 'Hounslow': (3.0030285097705134, 200.30285097705135), 'Islington': (3.440534747930312, 244.05347479303114), 'Kensington & Chelsea': (3.520
# ...

# %%
#Creating final dataframe
df = pd.DataFrame(AllBoroughMetrics)

# %%
df.head()
# Out:
#    Barking & Dagenham      Barnet      Bexley       Brent     Bromley  \
# 0            3.896131    3.130527    3.324508    3.446671    2.941012
# 1          289.613093  213.052681  232.450753  244.667078  194.101194
#
#        Camden     Croydon      Ealing     Enfield   Greenwich  ...  \
# 0    3.358212    3.157043    3.128508    3.250120    3.589197  ...
# 1  235.821163  215.704294  212.850769  225.012032  258.919747  ...
#
#        Merton      Newham   Redbridge  Richmond upon Thames   Southwark  \
# 0    3.455262    3.998745    3.403227              2.988356    3.590929
# 1  245.526246  299.874523  240.322692            198.835583  259.092882
#
#        Sutton  Tower Hamlets  Waltham Forest  Wandsworth  Westminster
# 0    3.002848       3.287004        4.367752    3.318996     3.687132
# 1  200.284838     228.700408      336.775154  231.899619   268.713165
#
# [2 rows x 32 columns]

# %%
dfT = df.transpose()

# %%
dfT.head()
# Out:
#                            0           1
# Barking & Dagenham  3.896131  289.613093
# Barnet              3.130527  213.052681
# Bexley              3.324508  232.450753
# Brent               3.446671  244.667078
# Bromley             2.941012  194.101194

# %%
dfT = dfT.reset_index()

# %%
dfT.head()
# Out:
#                 index         0           1
# 0  Barking & Dagenham  3.896131  289.613093
# 1              Barnet  3.130527  213.052681
# 2              Bexley  3.324508  232.450753
# 3               Brent  3.446671  244.667078
# 4             Bromley  2.941012  194.101194

# %%
#Renaming columns
dfT = dfT.rename(columns={'index': 'Boroughs', 0: '20 year ratio', 1: '20 year % change'})

# %%
dfT.head()
# Out:
#              Boroughs  20 year ratio  20 year % change
# 0  Barking & Dagenham       3.896131        289.613093
# 1              Barnet       3.130527        213.052681
# 2              Bexley       3.324508        232.450753
# 3               Brent       3.446671        244.667078
# 4             Bromley       2.941012        194.101194

# %%
print(dfT['20 year ratio'].mean())
print(dfT['20 year % change'].mean())
# Out:
# 3.4205277900932813
# 242.05277900932816

# %%
print(dfT['20 year ratio'].median())
print(dfT['20 year % change'].median())
# Out:
# 3.3712837187062332
# 237.1283718706233

# %%
GreatestIncrease = dfT.sort_values(by=['20 year % change','20 year ratio'],ascending=False)

# %%
GreatestIncrease.head(32)
# Out:
#                 Boroughs  20 year ratio  20 year % change
# 10               Hackney       4.387150        338.714960
# 29        Waltham Forest       4.367752        336.775154
# 23                Newham       3.998745        299.874523
# 21              Lewisham       3.949339        294.933926
# 0     Barking & Dagenham       3.896131        289.613093
# 12              Haringey       3.833316        283.331561
# 31           Westminster       3.687132        268.713165
# 26             Southwark       3.590929        259.092882
# 9              Greenwich       3.589197        258.919747
# 20               Lambeth       3.568262        256.826219
# 18  Kensington & Chelsea       3.520051        252.005065
# 22                Merton       3.455262        245.526246
# 3                  Brent       3.446671        244.667078
# 17             Islington       3.440535        244.053475
# 24             Redbridge       3.403227        240.322692
# ...

# %%
#Attempting Scatter Plot to check if 20 year ratio and 20 year % change are correlated

GreatestIncrease.plot.scatter(x='20 year ratio', y='20 year % change', alpha=0.5)
# Out:
# <AxesSubplot:xlabel='20 year ratio', ylabel='20 year % change'>

# %%
#Bar chart to compare average prices over the last two decades

GreatestIncrease.plot.bar('Boroughs','20 year % change').set(ylabel='20 year % change')
#FinalPlot.set_xticklabels(GreatestIncrease.Boroughs)
# Out:
# [Text(0, 0.5, '20 year % change')]

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# Based on the evaluation of the data from the London Datastore, the top three boroughs that have had the greatest increase in housing prices in the last two decades (2000-2020) are Hackney, Waltham Forest and Newham.
#
# For each of these boroughs the ratio of housing price increase as well as the percentage increase over the last two decades are listed below.
#
# Hackney
# 20-year ratio: 4.39
# 20-year % change: 338.71
#
# Waltham Forest
# 20-year ratio: 4.37
# 20-year % change: 336.77
#
# Newham
# 20-year ratio: 3.99
# 20-year % change: 299.87
#
# In 2000 the average housing price for each of these boroughs is listed below compared to their average price in 2020.
#
# Hackney
# 2000: 132727.50
# 2020: 582295.42
#
# Waltham Forest
# 2000: 103030.67
# 2020: 450012.39
#
# Newham
# 2000: 92887.329294
# 2020: 371432.765292
#
#
# And finally the mean and median change in the housing ratio and percentage change for all boroughs is included below.
#
# Mean
# 20-year ratio:3.42
# 20-year %change:242.05
#
# Median
# 20-year ratio:3.37
# 20-year %change:237.12
#
# The mean and median values are close leading us to believe that the majority (if not all) of the boroughs have experienced a similar amount of increase in housing prices in the last two decades. Hackney and Waltham Forest however standout as the two boroughs that have seen housing prices increase a lot more than all other boroughs.Taking a look at the growth trend for these two boroughs reveals that a majority of this housing price increase happened around 2010 and later.

# %%
OnlyHackney = OnlyBoroughs[OnlyBoroughs['Boroughs'] == 'Brent']
OnlyWaltham = OnlyBoroughs[OnlyBoroughs['Boroughs'] == 'Waltham Forest']

ax1 = OnlyHackney.plot.line(x='Month',y='Prices')
ax1.set_title('Hackney')
ax1.set_ylabel('Price')
ax1.set_xlabel('Month')

ax2 = OnlyWaltham.plot.line(x='Month',y='Prices')
ax2.set_title('Waltham Forest')
ax2.set_ylabel('Price')
ax2.set_xlabel('Month')
# Out:
# Text(0.5, 0, 'Month')
